# %% [markdown]
# # Instructor notes
#
# The three learner tracks form the complete workshop. Use the [instructor guide](../guides/instructor_guide.md), [assessment rubric](../guides/alignment_and_assessment.md), and [lesson adaptation template](../templates/instructor_adaptation.md).
#
# Run snapshot verification and the offline validation script before delivery. Choose local framing and review arrangements; do not infer award objectives or approvals.
